# %%
#Create 3 variables — your name, your age, and your GPA (like 8.5). Print all three.

name="Arnab Kanu"
age=25
Gpa=8.7

print(name, age, Gpa, sep="\n")
print()


#What is the data type of each of these?
x = 10
y = 10.0
z = "10"
w = True

print("x=int","y=float","z=string","w=boolean",sep="\n")


a = 5
b = 2
print(type(a/b))
print()

x = 100
x = "hundred"
print(x)
# Out:
# Arnab Kanu
# 25
# 8.7
#
# x=int
# y=float
# z=string
# w=boolean
# <class 'float'>
#
# hundred

# %%
#print(10 // 3)
print (3.0)
#print(10 % 3)
print (3)
print()


x = 5
#print(x > 3 and x < 10)
print(True)
#print(x > 3 and x > 10)
print(False)
print()

a=2 ** 10
print(a)
print()

x = 10
x += 5
x *= 2
print(x)
print()

print(not True)
print(not False)
print(True or False)
print(True and False)
# Out:
# 3.0
# 3
#
# True
# False
#
# 1024
#
# 30
#
# False
# True
# True
# False

# %%
print(15 % 4)
print(15 // 4)
print(15 / 4)
print(10 == 10.0)
# Out:
# 3
# 3
# 3.75
# True
