# %%
#find 2nd largest no

n=int(input())
temp=0
temp2=-1
while n>0:
  d=n%10
  if d>temp:
    temp2=temp
    temp=d
  elif d<temp and d>temp2 :
    temp2=d
  n=n//10
print(temp2)

# %%
#find longest consecutive sequence of identical digits.

n=int(input())
temp=-1
c=0
while n>0:
    d=n%10
    if d==temp:
        c+=1
        seq=c
    else:
        c=1
    temp=d
    n=n//10    
print(c)
